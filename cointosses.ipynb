# %%
import pandas as pd

c = pd.read_csv("cointosses.csv")
display(c)
# Out:
#      Unnamed: 0                                              input  fake  \
# 0             1  OORORRORRRORROROORORROOOROROORRRORORROOORRROOO...     1
# 1             2  OORROOOROROOOROORRORRORRROORRRROORROROROORROOR...     1
# 2             3  ORROOOROROOROORRRROORORORROORORRROORORROROROOR...     1
# 3             4  ORROROORORROROOORROORROROROOROOORROROROROROROR...     1
# 4             5  OORORRORROROOORORRORORROORRORROORRROROOROROROO...     1
# ..          ...                                                ...   ...
# 251         252  ORRRORRRORORROOROOOOOROROOOROROROROOOORRRROORR...     0
# 252         253  ORORRRRORRROOOOROOORRRROROROORRRRORRRRRORORORR...     0
# 253         254  OOROOORRRRORRROOOROORORRORORROROOROROORORROORO...     0
# 254         255  OOORRRRRORRROROOOOOOORRORROOROROORRRRROORROOOO...     0
# 255         256  ORRORORROROOROOOOOORROORRROROOOOORORORORRROORO...     0
#
#      pierwszy_O  liczba_serii  liczba_O  max_seria  runtest_z      sd10  \
# ...
